# %%
import pandas as pd
import pysal as ps

# %%
def dbf2DF(dbfile, geographic_boundary, year): #Reads in DBF files and returns Pandas DF
        # you must put 'year' and 'geographic_boundary' in quotes
        # geographic_boundary is the state you have data for or "AllStates"
    db = ps.open(dbfile) #Pysal to open DBF
    d = {col: db.by_col(col) for col in db.header} #Convert dbf to dictionary
    pandasDF = pd.DataFrame(d) #Convert to Pandas DF
    db.close()
    pandasDF.to_csv('Pres_bycounty_' + geographic_boundary + '_' + year + '.csv')
    return pandasDF.head()

# %%
dbf2DF('elpo04p020.dbf', 'AllStates', '2004')
# Out:
#         AREA                                       COUNTY  EL2004P020   FIPS  \
# 0   7.009898    State House District 8, Denali-University         8.0  02008
# 1  16.636605  State House District 37, Bristol Bay-Aleuti        37.0  02037
# 2  12.090892  State House District 12, Richardson-Glenn H        12.0  02012
# 3   0.043665      State House District 13, Greater Palmer        13.0  02013
# 4   0.025584     State House District 14, Greater Wasilla        14.0  02014
#
#   OBJECTID PERCENT_DE PERCENT_OT PERCENT_RE   PERIMETER STATE STATE_FIPS  \
# 0        1       44.5        4.4       51.1   18.211322    AK         02
# 1        2       61.7        2.3         36  168.791686    AK         02
# 2        3       28.5          3       68.5   36.210830    AK         02
# 3        4       30.1        3.1       66.8    1.307273    AK         02
# 4        5       28.3        2.8       68.9    1.040823    AK         02
#
#   SYMBOL_COD TOTAL_VOTE VOTE_DEM VOTE_OTH VOTE_REP
# 0          4      12942     5758      569     6615
# 1          8       8446     5208      192     3046
# 2          3      11845     3387      350     8108
# 3          3      16012     4819      491    10702
# 4          3      15548     4403      428    10717
